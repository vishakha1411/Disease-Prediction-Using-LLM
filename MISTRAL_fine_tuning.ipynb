# %%
# !pip install trl
# Out:
# Collecting trl
#   Downloading trl-0.25.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from trl) (1.11.0)
# Requirement already satisfied: datasets>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from trl) (4.0.0)
# Requirement already satisfied: transformers>=4.56.1 in /usr/local/lib/python3.12/dist-packages (from trl) (4.57.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (2.8.0+cu126)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (2025.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->trl) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->trl) (0.22.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl) (2025.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.0.0->trl) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate>=1.4.0->trl) (3.0.3)
# Downloading trl-0.25.1-py3-none-any.whl (465 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.5/465.5 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: trl
# Successfully installed trl-0.25.1

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %% [markdown]
# # **READING AND PREPARING DATA**

# %%
import pandas as pd
df=pd.read_csv('/content/DiseaseAndSymptoms.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
# Assuming your dataframe is named df

# Get all symptom columns
symptom_cols = [col for col in df.columns if col.startswith("Symptom_")]

# Create the combined Symptoms column
df["Symptoms"] = df[symptom_cols].apply(
    lambda row: ", ".join([
        str(x).replace("_", " ")               # replace underscores
        for x in row.dropna()                  # remove NaN
        if str(x).strip() != ""                # remove empty strings
    ]),
    axis=1
)
df.Symptoms
# Out:
# 0       itching,  skin rash,  nodal skin eruptions,  d...
# 1        skin rash,  nodal skin eruptions,  dischromic...
# 2       itching,  nodal skin eruptions,  dischromic  p...
# 3               itching,  skin rash,  dischromic  patches
# 4              itching,  skin rash,  nodal skin eruptions
#                               ...
# 4915     vomiting,  headache,  nausea,  spinning movem...
# 4916     skin rash,  pus filled pimples,  blackheads, ...
# 4917     burning micturition,  bladder discomfort,  fo...
# 4918     skin rash,  joint pain,  skin peeling,  silve...
# 4919     skin rash,  high fever,  blister,  red sore a...
# Name: Symptoms, Length: 4920, dtype: object

# %%
df.drop(symptom_cols, axis=1, inplace=True)
df
# Out:
#                                       Disease  \
# 0                            Fungal infection
# 1                            Fungal infection
# 2                            Fungal infection
# 3                            Fungal infection
# 4                            Fungal infection
# ...                                       ...
# 4915  (vertigo) Paroymsal  Positional Vertigo
# 4916                                     Acne
# 4917                  Urinary tract infection
# 4918                                Psoriasis
# 4919                                 Impetigo
#
#                                                Symptoms
# 0     itching,  skin rash,  nodal skin eruptions,  d...
# 1      skin rash,  nodal skin eruptions,  dischromic...
# 2     itching,  nodal skin eruptions,  dischromic  p...
# 3             itching,  skin rash,  dischromic  patches
# 4            itching,  skin rash,  nodal skin eruptions
# ...                                                 ...
# 4915   vomiting,  headache,  nausea,  spinning movem...
# 4916   skin rash,  pus filled pimples,  blackheads, ...
# 4917   burning micturition,  bladder discomfort,  fo...
# 4918   skin rash,  joint pain,  skin peeling,  silve...
# 4919   skin rash,  high fever,  blister,  red sore a...
#
# [4920 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
import json
df=df.sample(frac=1)
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Function to write JSONL
def write_jsonl(df, filename):
    with open(filename, "w") as f:
        for _, row in df.iterrows():
            record = {
                "instruction": "Identify the disease pattern based on symptoms.",
                "input": row["Symptoms"],
                "output": (
                    f"Disease: {row['Disease']}\n"
                    f"Explanation: These symptoms frequently match {row['Disease']} patterns in the dataset.\n"
                    "Note: This is not medical advice."
                )
            }
            f.write(json.dumps(record) + "\n")

write_jsonl(train_df, "train.jsonl")
write_jsonl(test_df, "test.jsonl")

# %%
import json

def load_jsonl(path):
    data = []
    with open(path, "r") as f:
        for line in f:
            data.append(json.loads(line))
    return data

train_raw = load_jsonl("/content/train.jsonl")
test_raw  = load_jsonl("/content/test.jsonl")

# ---------- BUILD TRAIN PROMPTS ----------
train_data = []

for row in train_raw:
    prompt = (
        f"{row['instruction']}\n"
        f"Symptoms: {row['input']}\n\n"
    )

    completion = row["output"]   # already formatted exactly as required

    train_data.append({
        "prompt": prompt,
        "completion": completion
    })

# ---------- BUILD TEST PROMPTS ----------
test_data = []
for row in test_raw:
    prompt = (
        f"{row['instruction']}\n"
        f"Symptoms: {row['input']}\n"
    )
    test_data.append({"prompt": prompt, "completion": ""})  # empty completion for eval

# %%
train_data
# Out:
# [{'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  indigestion,  loss of appetite,  abdominal pain,  passage of gases,  internal itching\n\n',
#   'completion': 'Disease: Peptic ulcer diseae\nExplanation: These symptoms frequently match Peptic ulcer diseae patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  fatigue,  cough,  high fever,  breathlessness,  sweating,  malaise,  phlegm,  chest pain,  fast heart rate,  rusty sputum\n\n',
#   'completion': 'Disease: Pneumonia\nExplanation: These symptoms frequently match Pneumonia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle wasting,  patches in throat,  high fever,  extra marital contacts\n\n',
#   'completion': 'Disease: AIDS\nExplanation: These symptoms frequently match AIDS patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  high fever,  sweating,  headache,  nausea,  diarrhoea,  muscle pain\n\n',
#   'completion': 'Disease: Malaria\nExplanation: These symptoms frequently match Malaria patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  continuous sneezing,  chills,  cough,  high fever,  headache,  swelled lymph nodes,  malaise,  phlegm,  throat irritation,  redness of eyes,  sinus pressure,  runny nose,  congestion,  chest pain,  loss of smell,  muscle pain\n\n',
#   'completion': 'Disease: Common Cold\nExplanation: These symptoms frequently match Common Cold patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  fatigue,  anxiety,  sweating,  headache,  nausea,  blurred and distorted vision,  excessive hunger,  drying and tingling lips,  slurred speech,  irritability,  palpitations\n\n',
#   'completion': 'Disease: Hypoglycemia\nExplanation: These symptoms frequently match Hypoglycemia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  high fever,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes,  acute liver failure,  coma,  stomach bleeding\n\n',
#   'completion': 'Disease: Hepatitis E\nExplanation: These symptoms frequently match Hepatitis E patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  yellowish skin,  abdominal pain,  swelling of stomach,  history of alcohol consumption,  fluid overload\n\n',
#   'completion': 'Disease: Alcoholic hepatitis\nExplanation: These symptoms frequently match Alcoholic hepatitis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  cramps,  bruising,  obesity,  swollen legs,  swollen blood vessels,  prominent veins on calf\n\n',
#   'completion': 'Disease: Varicose veins\nExplanation: These symptoms frequently match Varicose veins patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  stomach pain,  spotting  urination\n\n',
#   'completion': 'Disease: Drug Reaction\nExplanation: These symptoms frequently match Drug Reaction patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  high fever,  yellowish skin,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes,  acute liver failure,  coma,  stomach bleeding\n\n',
#   'completion': 'Disease: Hepatitis E\nExplanation: These symptoms frequently match Hepatitis E patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  acidity,  indigestion,  headache,  blurred and distorted vision,  excessive hunger,  stiff neck,  depression,  irritability\n\n',
#   'completion': 'Disease: Migraine\nExplanation: These symptoms frequently match Migraine patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  joint pain,  skin peeling,  silver like dusting,  small dents in nails,  inflammatory nails\n\n',
#   'completion': 'Disease: Psoriasis\nExplanation: These symptoms frequently match Psoriasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  sunken eyes,  dehydration,  diarrhoea\n\n',
#   'completion': 'Disease: Gastroenteritis\nExplanation: These symptoms frequently match Gastroenteritis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Hepatitis D\nExplanation: These symptoms frequently match Hepatitis D patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  fatigue,  cough,  high fever,  breathlessness,  sweating,  malaise,  phlegm,  chest pain,  fast heart rate,  rusty sputum\n\n',
#   'completion': 'Disease: Pneumonia\nExplanation: These symptoms frequently match Pneumonia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  headache,  nausea,  spinning movements,  loss of balance,  unsteadiness\n\n',
#   'completion': 'Disease: (vertigo) Paroymsal  Positional Vertigo\nExplanation: These symptoms frequently match (vertigo) Paroymsal  Positional Vertigo patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  neck pain,  knee pain,  hip joint pain,  swelling joints,  painful walking\n\n',
#   'completion': 'Disease: Osteoarthristis\nExplanation: These symptoms frequently match Osteoarthristis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  fatigue,  lethargy,  high fever,  headache,  loss of appetite,  mild fever,  swelled lymph nodes,  malaise,  red spots over body\n\n',
#   'completion': 'Disease: Chicken pox\nExplanation: These symptoms frequently match Chicken pox patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  vomiting,  fatigue,  weight loss,  yellowish skin,  dark urine,  abdominal pain\n\n',
#   'completion': 'Disease: Jaundice\nExplanation: These symptoms frequently match Jaundice patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  stomach pain,  burning micturition,  spotting  urination\n\n',
#   'completion': 'Disease: Drug Reaction\nExplanation: These symptoms frequently match Drug Reaction patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  weight gain,  cold hands and feets,  mood swings,  lethargy,  dizziness,  puffy face and eyes,  enlarged thyroid,  brittle nails,  swollen extremeties,  depression,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hypothyroidism\nExplanation: These symptoms frequently match Hypothyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  joint pain,  skin peeling,  silver like dusting,  small dents in nails,  inflammatory nails\n\n',
#   'completion': 'Disease: Psoriasis\nExplanation: These symptoms frequently match Psoriasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  headache,  chest pain,  dizziness,  loss of balance,  lack of concentration\n\n',
#   'completion': 'Disease: Hypertension \nExplanation: These symptoms frequently match Hypertension  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  headache,  weakness of one body side,  altered sensorium\n\n',
#   'completion': 'Disease: Paralysis (brain hemorrhage)\nExplanation: These symptoms frequently match Paralysis (brain hemorrhage) patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  headache,  chest pain,  dizziness,  loss of balance,  lack of concentration\n\n',
#   'completion': 'Disease: Hypertension \nExplanation: These symptoms frequently match Hypertension  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  neck pain,  knee pain,  hip joint pain,  swelling joints,  painful walking\n\n',
#   'completion': 'Disease: Osteoarthristis\nExplanation: These symptoms frequently match Osteoarthristis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  breathlessness,  sweating,  chest pain\n\n',
#   'completion': 'Disease: Heart attack\nExplanation: These symptoms frequently match Heart attack patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  pus filled pimples,  blackheads,  scurring\n\n',
#   'completion': 'Disease: Acne\nExplanation: These symptoms frequently match Acne patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  stomach pain,  ulcers on tongue,  vomiting,  cough,  chest pain\n\n',
#   'completion': 'Disease: GERD\nExplanation: These symptoms frequently match GERD patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  joint pain,  vomiting,  fatigue,  high fever,  headache,  nausea,  loss of appetite,  pain behind the eyes,  back pain,  malaise,  muscle pain,  red spots over body\n\n',
#   'completion': 'Disease: Dengue\nExplanation: These symptoms frequently match Dengue patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  neck pain,  knee pain,  hip joint pain,  swelling joints\n\n',
#   'completion': 'Disease: Osteoarthristis\nExplanation: These symptoms frequently match Osteoarthristis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle wasting,  patches in throat,  high fever,  extra marital contacts\n\n',
#   'completion': 'Disease: AIDS\nExplanation: These symptoms frequently match AIDS patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  high fever,  sweating,  headache,  nausea,  diarrhoea,  muscle pain\n\n',
#   'completion': 'Disease: Malaria\nExplanation: These symptoms frequently match Malaria patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  pus filled pimples,  blackheads,  scurring\n\n',
#   'completion': 'Disease: Acne\nExplanation: These symptoms frequently match Acne patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  headache,  chest pain,  dizziness,  loss of balance\n\n',
#   'completion': 'Disease: Hypertension \nExplanation: These symptoms frequently match Hypertension  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  headache,  altered sensorium\n\n',
#   'completion': 'Disease: Paralysis (brain hemorrhage)\nExplanation: These symptoms frequently match Paralysis (brain hemorrhage) patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  nausea,  spinning movements,  loss of balance,  unsteadiness\n\n',
#   'completion': 'Disease: (vertigo) Paroymsal  Positional Vertigo\nExplanation: These symptoms frequently match (vertigo) Paroymsal  Positional Vertigo patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  sunken eyes,  dehydration,  diarrhoea\n\n',
#   'completion': 'Disease: Gastroenteritis\nExplanation: These symptoms frequently match Gastroenteritis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  back pain,  weakness in limbs,  neck pain,  dizziness,  loss of balance\n\n',
#   'completion': 'Disease: Cervical spondylosis\nExplanation: These symptoms frequently match Cervical spondylosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  mood swings,  weight loss,  restlessness,  sweating,  diarrhoea,  fast heart rate,  excessive hunger,  muscle weakness,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hyperthyroidism\nExplanation: These symptoms frequently match Hyperthyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  sunken eyes,  dehydration,  diarrhoea\n\n',
#   'completion': 'Disease: Gastroenteritis\nExplanation: These symptoms frequently match Gastroenteritis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  yellowish skin,  nausea,  loss of appetite,  yellowing of eyes,  family history\n\n',
#   'completion': 'Disease: Hepatitis C\nExplanation: These symptoms frequently match Hepatitis C patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  mood swings,  weight loss,  restlessness,  sweating,  diarrhoea,  excessive hunger,  muscle weakness,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hyperthyroidism\nExplanation: These symptoms frequently match Hyperthyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  lethargy,  high fever,  headache,  loss of appetite,  mild fever,  swelled lymph nodes,  malaise,  red spots over body\n\n',
#   'completion': 'Disease: Chicken pox\nExplanation: These symptoms frequently match Chicken pox patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  vomiting,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Chronic cholestasis\nExplanation: These symptoms frequently match Chronic cholestasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  burning micturition,  spotting  urination\n\n',
#   'completion': 'Disease: Drug Reaction\nExplanation: These symptoms frequently match Drug Reaction patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  nodal skin eruptions,  dischromic  patches\n\n',
#   'completion': 'Disease: Fungal infection\nExplanation: These symptoms frequently match Fungal infection patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  yellowish skin,  nausea,  loss of appetite,  yellowing of eyes,  family history\n\n',
#   'completion': 'Disease: Hepatitis C\nExplanation: These symptoms frequently match Hepatitis C patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  high fever,  blister,  red sore around nose\n\n',
#   'completion': 'Disease: Impetigo\nExplanation: These symptoms frequently match Impetigo patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  fatigue,  anxiety,  sweating,  headache,  nausea,  blurred and distorted vision,  excessive hunger,  drying and tingling lips,  slurred speech,  irritability,  palpitations\n\n',
#   'completion': 'Disease: Hypoglycemia\nExplanation: These symptoms frequently match Hypoglycemia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  weight loss,  restlessness,  irregular sugar level,  blurred and distorted vision,  obesity,  excessive hunger,  increased appetite,  polyuria\n\n',
#   'completion': 'Disease: Diabetes \nExplanation: These symptoms frequently match Diabetes  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  fatigue,  lethargy,  yellowish skin,  dark urine,  loss of appetite,  abdominal pain,  yellow urine,  yellowing of eyes,  malaise,  receiving blood transfusion,  receiving unsterile injections\n\n',
#   'completion': 'Disease: Hepatitis B\nExplanation: These symptoms frequently match Hepatitis B patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  yellowish skin,  abdominal pain,  swelling of stomach,  distention of abdomen,  history of alcohol consumption,  fluid overload\n\n',
#   'completion': 'Disease: Alcoholic hepatitis\nExplanation: These symptoms frequently match Alcoholic hepatitis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  high fever,  blister,  red sore around nose,  yellow crust ooze\n\n',
#   'completion': 'Disease: Impetigo\nExplanation: These symptoms frequently match Impetigo patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  continuous sneezing,  chills,  fatigue,  cough,  high fever,  headache,  swelled lymph nodes,  malaise,  phlegm,  throat irritation,  redness of eyes,  sinus pressure,  runny nose,  congestion,  chest pain,  loss of smell,  muscle pain\n\n',
#   'completion': 'Disease: Common Cold\nExplanation: These symptoms frequently match Common Cold patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  fatigue,  lethargy,  yellowish skin,  dark urine,  loss of appetite,  abdominal pain,  yellowing of eyes,  malaise,  receiving blood transfusion,  receiving unsterile injections\n\n',
#   'completion': 'Disease: Hepatitis B\nExplanation: These symptoms frequently match Hepatitis B patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  stomach pain,  burning micturition,  spotting  urination\n\n',
#   'completion': 'Disease: Drug Reaction\nExplanation: These symptoms frequently match Drug Reaction patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  pus filled pimples,  blackheads,  scurring\n\n',
#   'completion': 'Disease: Acne\nExplanation: These symptoms frequently match Acne patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  mood swings,  weight loss,  restlessness,  sweating,  diarrhoea,  fast heart rate,  excessive hunger,  muscle weakness,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hyperthyroidism\nExplanation: These symptoms frequently match Hyperthyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  weight loss,  restlessness,  lethargy,  irregular sugar level,  blurred and distorted vision,  obesity,  excessive hunger,  increased appetite,  polyuria\n\n',
#   'completion': 'Disease: Diabetes \nExplanation: These symptoms frequently match Diabetes  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  back pain,  weakness in limbs,  neck pain,  dizziness,  loss of balance\n\n',
#   'completion': 'Disease: Cervical spondylosis\nExplanation: These symptoms frequently match Cervical spondylosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  continuous sneezing,  chills,  fatigue,  cough,  high fever,  headache,  swelled lymph nodes,  malaise,  phlegm,  throat irritation,  redness of eyes,  sinus pressure,  runny nose,  congestion,  chest pain,  loss of smell,  muscle pain\n\n',
#   'completion': 'Disease: Common Cold\nExplanation: These symptoms frequently match Common Cold patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  cramps,  bruising,  obesity,  swollen legs,  swollen blood vessels,  prominent veins on calf\n\n',
#   'completion': 'Disease: Varicose veins\nExplanation: These symptoms frequently match Varicose veins patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  fatigue,  weight loss,  cough,  high fever,  breathlessness,  sweating,  loss of appetite,  mild fever,  yellowing of eyes,  swelled lymph nodes,  malaise,  phlegm,  chest pain,  blood in sputum\n\n',
#   'completion': 'Disease: Tuberculosis\nExplanation: These symptoms frequently match Tuberculosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  cramps,  bruising,  obesity,  swollen legs,  swollen blood vessels,  prominent veins on calf\n\n',
#   'completion': 'Disease: Varicose veins\nExplanation: These symptoms frequently match Varicose veins patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  cramps,  bruising,  swollen legs,  swollen blood vessels,  prominent veins on calf\n\n',
#   'completion': 'Disease: Varicose veins\nExplanation: These symptoms frequently match Varicose veins patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  pain during bowel movements,  pain in anal region,  bloody stool,  irritation in anus\n\n',
#   'completion': 'Disease: Dimorphic hemmorhoids(piles)\nExplanation: These symptoms frequently match Dimorphic hemmorhoids(piles) patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  fatigue,  anxiety,  sweating,  headache,  blurred and distorted vision,  excessive hunger,  drying and tingling lips,  slurred speech,  irritability,  palpitations\n\n',
#   'completion': 'Disease: Hypoglycemia\nExplanation: These symptoms frequently match Hypoglycemia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  indigestion,  abdominal pain,  passage of gases,  internal itching\n\n',
#   'completion': 'Disease: Peptic ulcer diseae\nExplanation: These symptoms frequently match Peptic ulcer diseae patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  vomiting,  yellowish skin,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Chronic cholestasis\nExplanation: These symptoms frequently match Chronic cholestasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  headache,  chest pain,  dizziness,  loss of balance,  lack of concentration\n\n',
#   'completion': 'Disease: Hypertension \nExplanation: These symptoms frequently match Hypertension  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  continuous sneezing,  shivering,  watering from eyes\n\n',
#   'completion': 'Disease: Allergy\nExplanation: These symptoms frequently match Allergy patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  cramps,  bruising,  obesity,  swollen legs,  swollen blood vessels,  prominent veins on calf\n\n',
#   'completion': 'Disease: Varicose veins\nExplanation: These symptoms frequently match Varicose veins patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle weakness,  stiff neck,  swelling joints,  movement stiffness,  painful walking\n\n',
#   'completion': 'Disease: Arthritis\nExplanation: These symptoms frequently match Arthritis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  fatigue,  cough,  high fever,  breathlessness,  sweating,  malaise,  phlegm,  chest pain,  fast heart rate,  rusty sputum\n\n',
#   'completion': 'Disease: Pneumonia\nExplanation: These symptoms frequently match Pneumonia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  vomiting,  fatigue,  weight loss,  high fever,  yellowish skin,  dark urine,  abdominal pain\n\n',
#   'completion': 'Disease: Jaundice\nExplanation: These symptoms frequently match Jaundice patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  high fever,  sweating,  headache,  nausea,  diarrhoea,  muscle pain\n\n',
#   'completion': 'Disease: Malaria\nExplanation: These symptoms frequently match Malaria patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  fatigue,  lethargy,  yellowish skin,  dark urine,  loss of appetite,  abdominal pain,  yellow urine,  yellowing of eyes,  malaise,  receiving blood transfusion,  receiving unsterile injections\n\n',
#   'completion': 'Disease: Hepatitis B\nExplanation: These symptoms frequently match Hepatitis B patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  burning micturition,  bladder discomfort,  foul smell of urine,  continuous feel of urine\n\n',
#   'completion': 'Disease: Urinary tract infection\nExplanation: These symptoms frequently match Urinary tract infection patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  weight gain,  mood swings,  lethargy,  dizziness,  puffy face and eyes,  enlarged thyroid,  brittle nails,  swollen extremeties,  depression,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hypothyroidism\nExplanation: These symptoms frequently match Hypothyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  fatigue,  weight loss,  high fever,  breathlessness,  sweating,  loss of appetite,  mild fever,  yellowing of eyes,  swelled lymph nodes,  malaise,  phlegm,  chest pain,  blood in sputum\n\n',
#   'completion': 'Disease: Tuberculosis\nExplanation: These symptoms frequently match Tuberculosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  weight gain,  cold hands and feets,  mood swings,  lethargy,  dizziness,  puffy face and eyes,  enlarged thyroid,  brittle nails,  swollen extremeties,  depression,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hypothyroidism\nExplanation: These symptoms frequently match Hypothyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  continuous sneezing,  chills,  fatigue,  cough,  high fever,  headache,  swelled lymph nodes,  malaise,  phlegm,  throat irritation,  redness of eyes,  sinus pressure,  runny nose,  congestion,  chest pain,  loss of smell,  muscle pain\n\n',
#   'completion': 'Disease: Common Cold\nExplanation: These symptoms frequently match Common Cold patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  cough,  high fever,  breathlessness,  sweating,  malaise,  phlegm,  chest pain,  fast heart rate,  rusty sputum\n\n',
#   'completion': 'Disease: Pneumonia\nExplanation: These symptoms frequently match Pneumonia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  nodal skin eruptions,  dischromic  patches\n\n',
#   'completion': 'Disease: Fungal infection\nExplanation: These symptoms frequently match Fungal infection patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  indigestion,  loss of appetite,  abdominal pain,  passage of gases\n\n',
#   'completion': 'Disease: Peptic ulcer diseae\nExplanation: These symptoms frequently match Peptic ulcer diseae patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  stomach pain,  burning micturition,  spotting  urination\n\n',
#   'completion': 'Disease: Drug Reaction\nExplanation: These symptoms frequently match Drug Reaction patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  chills,  joint pain,  vomiting,  fatigue,  high fever,  headache,  nausea,  loss of appetite,  pain behind the eyes,  back pain,  malaise,  muscle pain,  red spots over body\n\n',
#   'completion': 'Disease: Dengue\nExplanation: These symptoms frequently match Dengue patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  patches in throat,  high fever,  extra marital contacts\n\n',
#   'completion': 'Disease: AIDS\nExplanation: These symptoms frequently match AIDS patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  fatigue,  weight loss,  cough,  high fever,  breathlessness,  sweating,  loss of appetite,  mild fever,  yellowing of eyes,  swelled lymph nodes,  malaise,  phlegm,  chest pain,  blood in sputum\n\n',
#   'completion': 'Disease: Tuberculosis\nExplanation: These symptoms frequently match Tuberculosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  indigestion,  loss of appetite,  abdominal pain,  passage of gases,  internal itching\n\n',
#   'completion': 'Disease: Peptic ulcer diseae\nExplanation: These symptoms frequently match Peptic ulcer diseae patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  acidity,  indigestion,  headache,  blurred and distorted vision,  excessive hunger,  stiff neck,  depression,  irritability\n\n',
#   'completion': 'Disease: Migraine\nExplanation: These symptoms frequently match Migraine patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  yellowish skin,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Chronic cholestasis\nExplanation: These symptoms frequently match Chronic cholestasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  fatigue,  cough,  high fever,  breathlessness,  sweating,  malaise,  chest pain,  fast heart rate,  rusty sputum\n\n',
#   'completion': 'Disease: Pneumonia\nExplanation: These symptoms frequently match Pneumonia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  fatigue,  cough,  high fever,  breathlessness,  sweating,  loss of appetite,  mild fever,  yellowing of eyes,  swelled lymph nodes,  malaise,  phlegm,  chest pain,  blood in sputum\n\n',
#   'completion': 'Disease: Tuberculosis\nExplanation: These symptoms frequently match Tuberculosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  fatigue,  lethargy,  high fever,  headache,  loss of appetite,  mild fever,  swelled lymph nodes,  malaise,  red spots over body\n\n',
#   'completion': 'Disease: Chicken pox\nExplanation: These symptoms frequently match Chicken pox patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  breathlessness,  chest pain\n\n',
#   'completion': 'Disease: Heart attack\nExplanation: These symptoms frequently match Heart attack patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  yellowish skin,  abdominal pain,  swelling of stomach,  distention of abdomen,  history of alcohol consumption,  fluid overload\n\n',
#   'completion': 'Disease: Alcoholic hepatitis\nExplanation: These symptoms frequently match Alcoholic hepatitis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  high fever,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes,  acute liver failure,  coma,  stomach bleeding\n\n',
#   'completion': 'Disease: Hepatitis E\nExplanation: These symptoms frequently match Hepatitis E patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  fatigue,  high fever,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes,  acute liver failure,  coma,  stomach bleeding\n\n',
#   'completion': 'Disease: Hepatitis E\nExplanation: These symptoms frequently match Hepatitis E patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Hepatitis D\nExplanation: These symptoms frequently match Hepatitis D patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  high fever,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes,  acute liver failure,  coma,  stomach bleeding\n\n',
#   'completion': 'Disease: Hepatitis E\nExplanation: These symptoms frequently match Hepatitis E patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  fatigue,  lethargy,  high fever,  headache,  loss of appetite,  mild fever,  swelled lymph nodes,  malaise,  red spots over body\n\n',
#   'completion': 'Disease: Chicken pox\nExplanation: These symptoms frequently match Chicken pox patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  fatigue,  high fever,  headache,  loss of appetite,  mild fever,  swelled lymph nodes,  malaise,  red spots over body\n\n',
#   'completion': 'Disease: Chicken pox\nExplanation: These symptoms frequently match Chicken pox patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  high fever,  yellowish skin,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes,  acute liver failure,  coma,  stomach bleeding\n\n',
#   'completion': 'Disease: Hepatitis E\nExplanation: These symptoms frequently match Hepatitis E patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  yellowish skin,  loss of appetite,  yellowing of eyes,  family history\n\n',
#   'completion': 'Disease: Hepatitis C\nExplanation: These symptoms frequently match Hepatitis C patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  stomach pain,  burning micturition\n\n',
#   'completion': 'Disease: Drug Reaction\nExplanation: These symptoms frequently match Drug Reaction patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  vomiting,  fatigue,  weight loss,  high fever,  yellowish skin,  dark urine,  abdominal pain\n\n',
#   'completion': 'Disease: Jaundice\nExplanation: These symptoms frequently match Jaundice patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  stomach pain,  acidity,  ulcers on tongue,  vomiting,  cough,  chest pain\n\n',
#   'completion': 'Disease: GERD\nExplanation: These symptoms frequently match GERD patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  constipation,  pain during bowel movements,  pain in anal region,  bloody stool,  irritation in anus\n\n',
#   'completion': 'Disease: Dimorphic hemmorhoids(piles)\nExplanation: These symptoms frequently match Dimorphic hemmorhoids(piles) patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  mood swings,  weight loss,  restlessness,  sweating,  diarrhoea,  fast heart rate,  excessive hunger,  muscle weakness,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hyperthyroidism\nExplanation: These symptoms frequently match Hyperthyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  back pain,  weakness in limbs,  neck pain,  dizziness,  loss of balance\n\n',
#   'completion': 'Disease: Cervical spondylosis\nExplanation: These symptoms frequently match Cervical spondylosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  mood swings,  weight loss,  restlessness,  sweating,  diarrhoea,  fast heart rate,  excessive hunger,  muscle weakness,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hyperthyroidism\nExplanation: These symptoms frequently match Hyperthyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  joint pain,  skin peeling,  silver like dusting,  small dents in nails,  inflammatory nails\n\n',
#   'completion': 'Disease: Psoriasis\nExplanation: These symptoms frequently match Psoriasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  cramps,  bruising,  swollen legs,  swollen blood vessels,  prominent veins on calf\n\n',
#   'completion': 'Disease: Varicose veins\nExplanation: These symptoms frequently match Varicose veins patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  fatigue,  high fever,  headache,  nausea,  constipation,  diarrhoea,  toxic look (typhos),  belly pain\n\n',
#   'completion': 'Disease: Typhoid\nExplanation: These symptoms frequently match Typhoid patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  vomiting,  yellowish skin,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Chronic cholestasis\nExplanation: These symptoms frequently match Chronic cholestasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  burning micturition,  bladder discomfort,  continuous feel of urine\n\n',
#   'completion': 'Disease: Urinary tract infection\nExplanation: These symptoms frequently match Urinary tract infection patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  breathlessness,  sweating,  chest pain\n\n',
#   'completion': 'Disease: Heart attack\nExplanation: These symptoms frequently match Heart attack patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  sweating,  headache,  nausea,  diarrhoea,  muscle pain\n\n',
#   'completion': 'Disease: Malaria\nExplanation: These symptoms frequently match Malaria patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  fatigue,  lethargy,  yellowish skin,  loss of appetite,  abdominal pain,  yellow urine,  yellowing of eyes,  malaise,  receiving blood transfusion,  receiving unsterile injections\n\n',
#   'completion': 'Disease: Hepatitis B\nExplanation: These symptoms frequently match Hepatitis B patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  breathlessness,  sweating,  chest pain\n\n',
#   'completion': 'Disease: Heart attack\nExplanation: These symptoms frequently match Heart attack patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  continuous sneezing,  chills,  fatigue,  cough,  high fever,  headache,  swelled lymph nodes,  malaise,  phlegm,  throat irritation,  redness of eyes,  sinus pressure,  runny nose,  congestion,  chest pain,  loss of smell,  muscle pain\n\n',
#   'completion': 'Disease: Common Cold\nExplanation: These symptoms frequently match Common Cold patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  high fever,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes,  acute liver failure,  coma,  stomach bleeding\n\n',
#   'completion': 'Disease: Hepatitis E\nExplanation: These symptoms frequently match Hepatitis E patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  joint pain,  skin peeling,  silver like dusting,  small dents in nails,  inflammatory nails\n\n',
#   'completion': 'Disease: Psoriasis\nExplanation: These symptoms frequently match Psoriasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  continuous sneezing,  chills,  fatigue,  cough,  high fever,  headache,  swelled lymph nodes,  malaise,  phlegm,  throat irritation,  redness of eyes,  sinus pressure,  runny nose,  congestion,  chest pain,  loss of smell,  muscle pain\n\n',
#   'completion': 'Disease: Common Cold\nExplanation: These symptoms frequently match Common Cold patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  bladder discomfort,  foul smell of urine,  continuous feel of urine\n\n',
#   'completion': 'Disease: Urinary tract infection\nExplanation: These symptoms frequently match Urinary tract infection patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle weakness,  stiff neck,  swelling joints,  movement stiffness,  painful walking\n\n',
#   'completion': 'Disease: Arthritis\nExplanation: These symptoms frequently match Arthritis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  fatigue,  lethargy,  high fever,  headache,  loss of appetite,  mild fever,  swelled lymph nodes,  malaise,  red spots over body\n\n',
#   'completion': 'Disease: Chicken pox\nExplanation: These symptoms frequently match Chicken pox patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  high fever,  blister,  red sore around nose,  yellow crust ooze\n\n',
#   'completion': 'Disease: Impetigo\nExplanation: These symptoms frequently match Impetigo patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  sweating,  chest pain\n\n',
#   'completion': 'Disease: Heart attack\nExplanation: These symptoms frequently match Heart attack patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  weight loss,  restlessness,  lethargy,  irregular sugar level,  blurred and distorted vision,  obesity,  excessive hunger,  increased appetite,  polyuria\n\n',
#   'completion': 'Disease: Diabetes \nExplanation: These symptoms frequently match Diabetes  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  fatigue,  anxiety,  sweating,  headache,  nausea,  blurred and distorted vision,  excessive hunger,  drying and tingling lips,  slurred speech,  irritability,  palpitations\n\n',
# ...
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  headache,  nausea,  spinning movements,  loss of balance,  unsteadiness\n\n',
#   'completion': 'Disease: (vertigo) Paroymsal  Positional Vertigo\nExplanation: These symptoms frequently match (vertigo) Paroymsal  Positional Vertigo patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle wasting,  patches in throat,  high fever,  extra marital contacts\n\n',
#   'completion': 'Disease: AIDS\nExplanation: These symptoms frequently match AIDS patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  stomach pain,  burning micturition,  spotting  urination\n\n',
#   'completion': 'Disease: Drug Reaction\nExplanation: These symptoms frequently match Drug Reaction patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  pus filled pimples,  scurring\n\n',
#   'completion': 'Disease: Acne\nExplanation: These symptoms frequently match Acne patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  cough,  high fever,  breathlessness,  sweating,  malaise,  phlegm,  chest pain,  fast heart rate,  rusty sputum\n\n',
#   'completion': 'Disease: Pneumonia\nExplanation: These symptoms frequently match Pneumonia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  breathlessness,  sweating,  chest pain\n\n',
#   'completion': 'Disease: Heart attack\nExplanation: These symptoms frequently match Heart attack patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  back pain,  weakness in limbs,  neck pain,  dizziness,  loss of balance\n\n',
#   'completion': 'Disease: Cervical spondylosis\nExplanation: These symptoms frequently match Cervical spondylosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  high fever,  sweating,  headache,  nausea,  diarrhoea,  muscle pain\n\n',
#   'completion': 'Disease: Malaria\nExplanation: These symptoms frequently match Malaria patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  yellowish skin,  nausea,  loss of appetite,  yellowing of eyes,  family history\n\n',
#   'completion': 'Disease: Hepatitis C\nExplanation: These symptoms frequently match Hepatitis C patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  continuous sneezing,  shivering,  chills,  watering from eyes\n\n',
#   'completion': 'Disease: Allergy\nExplanation: These symptoms frequently match Allergy patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle weakness,  stiff neck,  swelling joints,  movement stiffness,  painful walking\n\n',
#   'completion': 'Disease: Arthritis\nExplanation: These symptoms frequently match Arthritis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  anxiety,  sweating,  headache,  nausea,  blurred and distorted vision,  excessive hunger,  drying and tingling lips,  slurred speech,  irritability,  palpitations\n\n',
#   'completion': 'Disease: Hypoglycemia\nExplanation: These symptoms frequently match Hypoglycemia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  back pain,  weakness in limbs,  neck pain,  dizziness,  loss of balance\n\n',
#   'completion': 'Disease: Cervical spondylosis\nExplanation: These symptoms frequently match Cervical spondylosis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  vomiting,  yellowish skin,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Chronic cholestasis\nExplanation: These symptoms frequently match Chronic cholestasis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  fatigue,  lethargy,  yellowish skin,  dark urine,  loss of appetite,  abdominal pain,  yellow urine,  yellowing of eyes,  malaise,  receiving blood transfusion,  receiving unsterile injections\n\n',
#   'completion': 'Disease: Hepatitis B\nExplanation: These symptoms frequently match Hepatitis B patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  acidity,  indigestion,  headache,  blurred and distorted vision,  excessive hunger,  stiff neck,  depression,  irritability,  visual disturbances\n\n',
#   'completion': 'Disease: Migraine\nExplanation: These symptoms frequently match Migraine patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  cough,  high fever,  breathlessness,  sweating,  malaise,  phlegm,  chest pain,  fast heart rate,  rusty sputum\n\n',
#   'completion': 'Disease: Pneumonia\nExplanation: These symptoms frequently match Pneumonia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  vomiting,  high fever,  headache,  nausea,  diarrhoea,  muscle pain\n\n',
#   'completion': 'Disease: Malaria\nExplanation: These symptoms frequently match Malaria patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  yellowish skin,  abdominal pain,  swelling of stomach,  distention of abdomen,  history of alcohol consumption\n\n',
#   'completion': 'Disease: Alcoholic hepatitis\nExplanation: These symptoms frequently match Alcoholic hepatitis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  acidity,  indigestion,  headache,  blurred and distorted vision,  excessive hunger,  stiff neck,  depression,  irritability,  visual disturbances\n\n',
#   'completion': 'Disease: Migraine\nExplanation: These symptoms frequently match Migraine patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle weakness,  stiff neck,  swelling joints,  movement stiffness,  painful walking\n\n',
#   'completion': 'Disease: Arthritis\nExplanation: These symptoms frequently match Arthritis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  breathlessness,  sweating,  chest pain\n\n',
#   'completion': 'Disease: Heart attack\nExplanation: These symptoms frequently match Heart attack patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  high fever,  blister,  red sore around nose,  yellow crust ooze\n\n',
#   'completion': 'Disease: Impetigo\nExplanation: These symptoms frequently match Impetigo patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  pus filled pimples,  blackheads,  scurring\n\n',
#   'completion': 'Disease: Acne\nExplanation: These symptoms frequently match Acne patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  burning micturition,  bladder discomfort,  foul smell of urine,  continuous feel of urine\n\n',
#   'completion': 'Disease: Urinary tract infection\nExplanation: These symptoms frequently match Urinary tract infection patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Hepatitis D\nExplanation: These symptoms frequently match Hepatitis D patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  constipation,  pain during bowel movements,  pain in anal region,  bloody stool,  irritation in anus\n\n',
#   'completion': 'Disease: Dimorphic hemmorhoids(piles)\nExplanation: These symptoms frequently match Dimorphic hemmorhoids(piles) patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  cough,  high fever,  breathlessness,  family history,  mucoid sputum\n\n',
#   'completion': 'Disease: Bronchial Asthma\nExplanation: These symptoms frequently match Bronchial Asthma patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  blackheads,  scurring\n\n',
#   'completion': 'Disease: Acne\nExplanation: These symptoms frequently match Acne patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  fatigue,  anxiety,  sweating,  nausea,  blurred and distorted vision,  excessive hunger,  drying and tingling lips,  slurred speech,  irritability,  palpitations\n\n',
#   'completion': 'Disease: Hypoglycemia\nExplanation: These symptoms frequently match Hypoglycemia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  weight gain,  cold hands and feets,  mood swings,  lethargy,  dizziness,  puffy face and eyes,  enlarged thyroid,  brittle nails,  swollen extremeties,  depression,  irritability,  abnormal menstruation\n\n',
#   'completion': 'Disease: Hypothyroidism\nExplanation: These symptoms frequently match Hypothyroidism patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  fatigue,  yellowish skin,  dark urine,  nausea,  abdominal pain,  yellowing of eyes\n\n',
#   'completion': 'Disease: Hepatitis D\nExplanation: These symptoms frequently match Hepatitis D patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  fatigue,  high fever,  headache,  nausea,  constipation,  abdominal pain,  diarrhoea,  toxic look (typhos),  belly pain\n\n',
#   'completion': 'Disease: Typhoid\nExplanation: These symptoms frequently match Typhoid patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  vomiting,  headache,  nausea,  spinning movements,  loss of balance,  unsteadiness\n\n',
#   'completion': 'Disease: (vertigo) Paroymsal  Positional Vertigo\nExplanation: These symptoms frequently match (vertigo) Paroymsal  Positional Vertigo patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  burning micturition,  spotting  urination\n\n',
#   'completion': 'Disease: Drug Reaction\nExplanation: These symptoms frequently match Drug Reaction patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  chills,  fatigue,  high fever,  breathlessness,  sweating,  malaise,  phlegm,  chest pain,  fast heart rate,  rusty sputum\n\n',
#   'completion': 'Disease: Pneumonia\nExplanation: These symptoms frequently match Pneumonia patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  pain during bowel movements,  pain in anal region,  bloody stool,  irritation in anus\n\n',
#   'completion': 'Disease: Dimorphic hemmorhoids(piles)\nExplanation: These symptoms frequently match Dimorphic hemmorhoids(piles) patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  skin rash,  nodal skin eruptions,  dischromic  patches\n\n',
#   'completion': 'Disease: Fungal infection\nExplanation: These symptoms frequently match Fungal infection patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms: itching,  fatigue,  lethargy,  yellowish skin,  dark urine,  loss of appetite,  abdominal pain,  yellow urine,  yellowing of eyes,  malaise,  receiving blood transfusion,  receiving unsterile injections\n\n',
#   'completion': 'Disease: Hepatitis B\nExplanation: These symptoms frequently match Hepatitis B patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  skin rash,  chills,  joint pain,  vomiting,  fatigue,  headache,  nausea,  loss of appetite,  pain behind the eyes,  back pain,  malaise,  muscle pain,  red spots over body\n\n',
#   'completion': 'Disease: Dengue\nExplanation: These symptoms frequently match Dengue patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle weakness,  stiff neck,  swelling joints,  movement stiffness,  painful walking\n\n',
#   'completion': 'Disease: Arthritis\nExplanation: These symptoms frequently match Arthritis patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  headache,  chest pain,  dizziness,  loss of balance,  lack of concentration\n\n',
#   'completion': 'Disease: Hypertension \nExplanation: These symptoms frequently match Hypertension  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  muscle wasting,  patches in throat,  high fever,  extra marital contacts\n\n',
#   'completion': 'Disease: AIDS\nExplanation: These symptoms frequently match AIDS patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  headache,  chest pain,  dizziness,  loss of balance,  lack of concentration\n\n',
#   'completion': 'Disease: Hypertension \nExplanation: These symptoms frequently match Hypertension  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  fatigue,  weight loss,  restlessness,  lethargy,  irregular sugar level,  blurred and distorted vision,  obesity,  increased appetite,  polyuria\n\n',
#   'completion': 'Disease: Diabetes \nExplanation: These symptoms frequently match Diabetes  patterns in the dataset.\nNote: This is not medical advice.'},
#  {'prompt': 'Identify the disease pattern based on symptoms.\nSymptoms:  joint pain,  vomiting,  yellowish skin,  dark urine,  nausea,  loss of appetite,  abdominal pain,  diarrhoea,  mild fever,  yellowing of eyes,  muscle pain\n\n',
#   'completion': 'Disease: hepatitis A\nExplanation: These symptoms frequently match hepatitis A patterns in the dataset.\nNote: This is not medical advice.'},
#  ...]

# %%
from datasets import Dataset
train = pd.DataFrame(train_data)
test  = pd.DataFrame(test_data)

train_dataset = Dataset.from_pandas(train)
test_dataset  = Dataset.from_pandas(test)

# %% [markdown]
# # **LOADING MODEL - MISTRAL 7B**

# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: read).
# The token `intel` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `intel`

# %%
model_name = "mistralai/Mistral-7B-v0.1"

tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
#!pip install -U bitsandbytes
#!pip install accelerate peft

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=False,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,   # <-- ONLY this!
    torch_dtype=torch.bfloat16,
    device_map="cuda:0",
    trust_remote_code=True,
)

model.config.use_cache = False
model.config.pretraining_tp = 1
model.gradient_checkpointing_enable()
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# # **MODEL TRAINING - 2 EPOCHS**

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

from peft import LoraConfig
from trl import SFTTrainer, SFTConfig # Import SFTConfig


# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj","gate_proj"]
)

# Define SFT configuration, moving dataset_text_field here
sft_config = SFTConfig(
    output_dir="./results",
    num_train_epochs=2,
    per_device_train_batch_size=32,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=20,
    logging_steps=100,
    learning_rate=2e-4,
    weight_decay=0.001,
    bf16=True,
    fp16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant" # Moved from TrainingArguments
)

# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    peft_config=peft_config,
    processing_class=tokenizer,
    args=sft_config
)
# Out:
# Adding EOS to train dataset:   0%|          | 0/3936 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/3936 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/3936 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 2}.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: vishakhaagrawal_co22a8_16 (vishakhaagrawal_co22a8_16-delhi-technological-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/content/wandb/run-20251120_163600-ka5vi7y4</code>
# Syncing run <strong><a href='https://wandb.ai/vishakhaagrawal_co22a8_16-delhi-technological-university/huggingface/runs/ka5vi7y4' target="_blank">young-dream-4</a></strong> to <a href='https://wandb.ai/vishakhaagrawal_co22a8_16-delhi-technological-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vishakhaagrawal_co22a8_16-delhi-technological-university/huggingface' target="_blank">https://wandb.ai/vishakhaagrawal_co22a8_16-delhi-technological-university/huggingface</a>
#  View run at <a href='https://wandb.ai/vishakhaagrawal_co22a8_16-delhi-technological-university/huggingface/runs/ka5vi7y4' target="_blank">https://wandb.ai/vishakhaagrawal_co22a8_16-delhi-technological-university/huggingface/runs/ka5vi7y4</a>
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='246' max='246' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [246/246 4:19:31, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.138300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.007100</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# TrainOutput(global_step=246, training_loss=0.060041936614164494, metrics={'train_runtime': 15669.3909, 'train_samples_per_second': 0.502, 'train_steps_per_second': 0.016, 'total_flos': 3.1106997522530304e+16, 'train_loss': 0.060041936614164494, 'entropy': 0.9320875445137853, 'num_tokens': 709190.0, 'mean_token_accuracy': 0.998663534288821, 'epoch': 2.0})

# %% [markdown]
# # **SAVING THE FINE TUNED MODEL**

# %%
trainer.model.save_pretrained("mistral_lora")
tokenizer.save_pretrained("mistral_lora")
test_df.to_csv("test.csv", index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_path = "/content/drive/MyDrive/mistral_lora_adapter"

trainer.model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)

print("LoRA adapter saved to:", save_path)
# Out:
# LoRA adapter saved to: /content/drive/MyDrive/mistral_lora_adapter
